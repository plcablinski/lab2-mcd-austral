# %% [markdown]
# # **Data Wrangling**
# *Objetivo: Aprender manipulación y transformación de datos*
#
# *Dataset del Ejercicio: http://campus.lakeforest.edu/frank/FILES/MLFfiles/Bio150/Titanic/TitanicMETA.pdf*

# %% [markdown]
# > **Objetos Comunes en Datos**
#
# DataFrame:
#
# Se asemeja a una tabla con filas y columnas, donde cada columna puede contener un tipo de datos diferente. Permite realizar operaciones de análisis de datos de manera eficiente y ofrece funcionalidades específicas para la manipulación y visualización de datos tabulares. Tienen "funciones lambda", que permiten aplicar operaciones o transformaciones a los datos eficientemente.
#
# Serie:
#
# Se parece a un array unidimensional y está etiquetada, lo que significa que cada elemento de la serie tiene un índice asociado. Al igual que un dataframe está preparada para manipular datos.
#
#
# > **Lectura de archivos de datos**
#
#
# Pandas soporta la lectura de una amplia cantidad de formatos ([más info](http://pandas.pydata.org/pandas-docs/stable/io.html)):
#
# - read_csv
# - read_excel
# - read_hdf
# - read_sql
# - read_json
# - read_msgpack (experimental)
# - read_html
# - read_gbq (experimental)
# - read_stata
# - read_sas
# - read_clipboard
# - read_pickle

# %% [markdown]
# ---
# #### **Importar/Crear Datasets**
# ---

# %%
# Importamos librerías

import pandas as pd
import numpy as np

# %% [markdown]
# **Usando listas**

# %%
# Crear listas de datos
nombres = ['Juan', 'María', 'Pedro', 'Ana', 'Luisa']
edades = [25, 30, 35, 40, 45]
interes = ['Economía', 'Marketing', 'Medicina', 'Medicina', 'Diseño']

# Crear el DataFrame
data = {'Nombres': nombres, 'Edades': edades, 'Interés': interes} # Se lo alimenta usando un diccionario {'nombre_columna1':lista1_valores,'nombre_columna2':lista2_valores}
df = pd.DataFrame(data) # Transformamos el diccionario en DF
df
# Out:
#   Nombres  Edades    Interés
# 0    Juan      25   Economía
# 1   María      30  Marketing
# 2   Pedro      35   Medicina
# 3     Ana      40   Medicina
# 4   Luisa      45     Diseño

# %% [markdown]
# **Desde un CSV**

# %%
df = pd.read_csv(r'titanic3.csv', sep=',') # Estos suelen ser los parámetros que más se usan, la ruta hacia el archivo y el tipo del separador
df

# En caso de no saber cual es la dirección, pueden hacer "click derecho" en el archivo y ver la ruta del tipo "C/..../archivo.csv"
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female      29      0      0   24160  211,3375       B5        S    2
# 1       male  0,9167      1      2  113781    151,55  C22 C26        S   11
# 2     female       2      1      2  113781    151,55  C22 C26        S  NaN
# 3       male      30      1      2  113781    151,55  C22 C26        S  NaN
# 4     female      25      1      2  113781    151,55  C22 C26        S  NaN
# ...      ...     ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female    14,5      1      0    2665   14,4542      NaN        C  NaN
# 1305  female     NaN      1      0    2665   14,4542      NaN        C  NaN
# 1306    male    26,5      0      0    2656     7,225      NaN        C  NaN
# 1307    male      27      0      0    2670     7,225      NaN        C  NaN
# 1308    male      29      0      0  315082     7,875      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %% [markdown]
# Les dejo la documentación de read_csv por si quieren investigar más: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
#
# Otros parámetros a usar:
#
# *   sep: Permite especificar el separador
#
# > Ej: sep = '\t'
#
#
# *   dtype: permite especificar un tipo de dato, si no lo agarra bien
#
# > Ej: dtype = {'A':np.float64, 'B':np.int64, 'C':'str'}
#
#
# *   index_col: En caso de que quieras que una columna sea el indice
#
# > Ej: index_col = 2 va a agarrar la 3ra columna de la tabla (acordarse que la primera columna es 0)
#
# *  na_filter: Elimina las filas con algun Na
#
# > Ej: na_filter = True
#
# *  skip_blank_lines: Quita las que tienen celdas en blanco
#
# > Ej: skip_blank_lines = True

# %% [markdown]
# **Desde un Spreadsheet de Google**
#
# Nota: Esta forma solo en Colab

# %%
# Genero la conexión, valido autenticación
from google.colab import auth
auth.authenticate_user()
import gspread
from google.auth import default
from gspread_dataframe import get_as_dataframe, set_with_dataframe
creds, _ = default()
gc = gspread.authorize(creds)

# %%
wb = gc.open_by_url('https://docs.google.com/spreadsheets/d/16AiilYU0DbGnEoQsvPuLtRjLpDaK4dMOmrgSAGnyyp4')
sheet = wb.worksheet('titanic3')  # Direcciono a la hoja del spreadsheet
df = pd.DataFrame(sheet.get_all_values()).drop_duplicates() # Cargo el spreadsheet
df.columns = df.iloc[0] # Primera fila como columna
df = df.iloc[1:]
df
# Out:
# 0    pclass survived                                             name     sex  \
# 1         1        1                    Allen, Miss. Elisabeth Walton  female
# 2         1        1                   Allison, Master. Hudson Trevor    male
# 3         1        0                     Allison, Miss. Helen Loraine  female
# 4         1        0             Allison, Mr. Hudson Joshua Creighton    male
# 5         1        0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...     ...      ...                                              ...     ...
# 1305      3        0                             Zabour, Miss. Hileni  female
# 1306      3        0                            Zabour, Miss. Thamine  female
# 1307      3        0                        Zakarian, Mr. Mapriededer    male
# 1308      3        0                              Zakarian, Mr. Ortin    male
# 1309      3        0                               Zimmerman, Mr. Leo    male
#
# 0        age sibsp parch  ticket      fare    cabin embarked boat body  \
# 1         29     0     0   24160  211,3375       B5        S    2
# 2     0,9167     1     2  113781    151,55  C22 C26        S   11
# 3          2     1     2  113781    151,55  C22 C26        S
# 4         30     1     2  113781    151,55  C22 C26        S       135
# 5         25     1     2  113781    151,55  C22 C26        S
# ...      ...   ...   ...     ...       ...      ...      ...  ...  ...
# 1305    14,5     1     0    2665   14,4542                 C       328
# 1306             1     0    2665   14,4542                 C
# 1307    26,5     0     0    2656     7,225                 C       304
# 1308      27     0     0    2670     7,225                 C
# 1309      29     0     0  315082     7,875                 S
#
# 0                           home.dest
# 1                        St Louis, MO
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# 5     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1305
# 1306
# 1307
# 1308
# 1309
#
# [1309 rows x 14 columns]

# %% [markdown]
# ---
#
#
# #### **Explorar Dataframe**
#
#
# ---

# %%
# Transformo las columnas que se pueda a numerico:
for i in df:                                    # Barre columna por columna
  df[i] = pd.to_numeric(df[i], errors='ignore')  # Cambia a numerico, si no puede lo deja en string

# %%
# Primeras 10 filas
df.head(10)
# Out:
# 0   pclass  survived                                             name     sex  \
# 1        1         1                    Allen, Miss. Elisabeth Walton  female
# 2        1         1                   Allison, Master. Hudson Trevor    male
# 3        1         0                     Allison, Miss. Helen Loraine  female
# 4        1         0             Allison, Mr. Hudson Joshua Creighton    male
# 5        1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 6        1         1                              Anderson, Mr. Harry    male
# 7        1         1                Andrews, Miss. Kornelia Theodosia  female
# 8        1         0                           Andrews, Mr. Thomas Jr    male
# 9        1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 10       1         0                          Artagaveytia, Mr. Ramon    male
#
# 0      age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 1       29      0      0     24160  211,3375       B5        S    2    NaN
# 2   0,9167      1      2    113781    151,55  C22 C26        S   11    NaN
# 3        2      1      2    113781    151,55  C22 C26        S         NaN
# 4       30      1      2    113781    151,55  C22 C26        S       135.0
# 5       25      1      2    113781    151,55  C22 C26        S         NaN
# 6       48      0      0     19952     26,55      E12        S    3    NaN
# 7       63      1      0     13502   77,9583       D7        S   10    NaN
# 8       39      0      0    112050         0      A36        S         NaN
# 9       53      2      0     11769   51,4792     C101        S    D    NaN
# 10      71      0      0  PC 17609   49,5042                 C        22.0
#
# 0                         home.dest
# 1                      St Louis, MO
# 2   Montreal, PQ / Chesterville, ON
# 3   Montreal, PQ / Chesterville, ON
# 4   Montreal, PQ / Chesterville, ON
# 5   Montreal, PQ / Chesterville, ON
# 6                      New York, NY
# 7                        Hudson, NY
# 8                       Belfast, NI
# 9               Bayside, Queens, NY
# 10              Montevideo, Uruguay

# %%
# Últimas 10 filas
df.tail(10)
# Out:
# 0     pclass  survived                                     name     sex   age  \
# 1300       3         0                      Yasbeck, Mr. Antoni    male    27
# 1301       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female    15
# 1302       3         0                     Youseff, Mr. Gerious    male  45,5
# 1303       3         0                        Yousif, Mr. Wazli    male
# 1304       3         0                    Yousseff, Mr. Gerious    male
# 1305       3         0                     Zabour, Miss. Hileni  female  14,5
# 1306       3         0                    Zabour, Miss. Thamine  female
# 1307       3         0                Zakarian, Mr. Mapriededer    male  26,5
# 1308       3         0                      Zakarian, Mr. Ortin    male    27
# 1309       3         0                       Zimmerman, Mr. Leo    male    29
#
# 0     sibsp  parch  ticket     fare cabin embarked boat   body home.dest
# 1300      1      0    2659  14,4542              C    C    NaN
# 1301      1      0    2659  14,4542              C         NaN
# 1302      0      0    2628    7,225              C       312.0
# 1303      0      0    2647    7,225              C         NaN
# 1304      0      0    2627  14,4583              C         NaN
# 1305      1      0    2665  14,4542              C       328.0
# 1306      1      0    2665  14,4542              C         NaN
# 1307      0      0    2656    7,225              C       304.0
# 1308      0      0    2670    7,225              C         NaN
# 1309      0      0  315082    7,875              S         NaN

# %%
# Dimensiones de la tabla
print(f"filas:{df.shape[0]}")
print(f"columnas:{df.shape[1]}")
df.shape
# Out:
# filas:1309
# columnas:14
# (1309, 14)

# %%
# Memoria en bytes
memoria = df.memory_usage(index=True).sum()
print(f"La memoria usada: {memoria/1000} Kb")
memoria
# Out:
# La memoria usada: 146.74 Kb
# 146740

# %%
# Listar columnas
col_list = df.columns.values.tolist()
col_list
# Out:
# ['pclass',
#  'survived',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked',
#  'boat',
#  'body',
#  'home.dest']

# %%
# Tipo de datos
df.dtypes  # Nota: Observen que no es un método porque no tiene "()" es un atributo
# Out:
# 0
# pclass         int64
# survived       int64
# name          object
# sex           object
# age           object
# sibsp          int64
# parch          int64
# ticket        object
# fare          object
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
# Descripción rápida estadística
round(df.describe(),2)
# Out:
# 0       pclass  survived    sibsp    parch    body
# count  1309.00   1309.00  1309.00  1309.00  121.00
# mean      2.29      0.38     0.50     0.39  160.81
# std       0.84      0.49     1.04     0.87   97.70
# min       1.00      0.00     0.00     0.00    1.00
# 25%       2.00      0.00     0.00     0.00   72.00
# 50%       3.00      0.00     0.00     0.00  155.00
# 75%       3.00      1.00     1.00     0.00  256.00
# max       3.00      1.00     8.00     9.00  328.00

# %%
# Missings (contando valores por columnas)
df.count()
# al feature body le faltan casi todos los valores
# Out:
# 0
# pclass       1309
# survived     1309
# name         1309
# sex          1309
# age          1309
# sibsp        1309
# parch        1309
# ticket       1309
# fare         1309
# cabin        1309
# embarked     1309
# boat         1309
# body          121
# home.dest    1309
# dtype: int64

# %%
# Otra forma de ver null y tipos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 1 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       121 non-null    float64
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %% [markdown]
# **Exploramos Columnas**

# %%
# Seleccionar una columna
df['survived']
# Out:
# 1       1
# 2       1
# 3       0
# 4       0
# 5       0
#        ..
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# 1309    0
# Name: survived, Length: 1309, dtype: int64

# %%
# Vemos la frecuencia valores
df['pclass'].value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
# Vemos los valores únicos
df['pclass'].unique().tolist()
# Out:
# [1, 2, 3]

# %%
# Cantidad de valores únicos
df['pclass'].nunique()
# Out:
# 3

# %%
# Calculamos la suma
print("La suma: ",df['pclass'].sum())

# Calculamos la media
print("La media: ",df['pclass'].mean())

# Calculamos la mediana
print("La mediana: ",df['pclass'].median())

# Calculamos el desvío estandar
print("El desvío estandar: ",df['pclass'].std())

# Calculamos un percentil
print("El percentil 50 (mediana): ",df['pclass'].quantile(0.50))
# Out:
# La suma:  3004
# La media:  2.294881588999236
# La mediana:  3.0
# El desvío estandar:  0.8378360189701274
# El percentil 50 (mediana):  3.0

# %% [markdown]
# **Navegamos por el dataframe**

# %%
# Creamos un subset de columnas
df_subset = df[['pclass','survived']]
df_subset
# Out:
# 0     pclass  survived
# 1          1         1
# 2          1         1
# 3          1         0
# 4          1         0
# 5          1         0
# ...      ...       ...
# 1305       3         0
# 1306       3         0
# 1307       3         0
# 1308       3         0
# 1309       3         0
#
# [1309 rows x 2 columns]

# %%
# Quitamos duplicados
df_subset.drop_duplicates(inplace=True) # inplace=True es equivalente a df_subset = df_subset.drop_duplicates()
df_subset
# Out:
# <ipython-input-23-3077d7e64fbb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset.drop_duplicates(inplace=True) # inplace=True es equivalente a df_subset = df_subset.drop_duplicates()
# 0    pclass  survived
# 1         1         1
# 3         1         0
# 324       2         0
# 325       2         1
# 601       3         0
# 604       3         1

# %%
# Reset del índice
df_subset.reset_index(drop =True, inplace=True) # Si el drop es False, agrega el índice actual como una columna más
df_subset
# Out:
# 0  pclass  survived
# 0       1         1
# 1       1         0
# 2       2         0
# 3       2         1
# 4       3         0
# 5       3         1

# %%
# Indexamos por posición: [ini_fila:fin_fila, ini_col:fin_col]
df.iloc[-10:,:] # Filtramos solo las filas
# Out:
# 0     pclass  survived                                     name     sex   age  \
# 1300       3         0                      Yasbeck, Mr. Antoni    male    27
# 1301       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female    15
# 1302       3         0                     Youseff, Mr. Gerious    male  45,5
# 1303       3         0                        Yousif, Mr. Wazli    male
# 1304       3         0                    Yousseff, Mr. Gerious    male
# 1305       3         0                     Zabour, Miss. Hileni  female  14,5
# 1306       3         0                    Zabour, Miss. Thamine  female
# 1307       3         0                Zakarian, Mr. Mapriededer    male  26,5
# 1308       3         0                      Zakarian, Mr. Ortin    male    27
# 1309       3         0                       Zimmerman, Mr. Leo    male    29
#
# 0     sibsp  parch  ticket     fare cabin embarked boat   body home.dest
# 1300      1      0    2659  14,4542              C    C    NaN
# 1301      1      0    2659  14,4542              C         NaN
# 1302      0      0    2628    7,225              C       312.0
# 1303      0      0    2647    7,225              C         NaN
# 1304      0      0    2627  14,4583              C         NaN
# 1305      1      0    2665  14,4542              C       328.0
# 1306      1      0    2665  14,4542              C         NaN
# 1307      0      0    2656    7,225              C       304.0
# 1308      0      0    2670    7,225              C         NaN
# 1309      0      0  315082    7,875              S         NaN

# %%
# Indexamos por posición: [ini_fila:fin_fila, ini_col:fin_col]
df.iloc[-10:,2:9] # Filtramos las filas y columnas
# Out:
# 0                                        name     sex   age  sibsp  parch  \
# 1300                      Yasbeck, Mr. Antoni    male    27      1      0
# 1301  Yasbeck, Mrs. Antoni (Selini Alexander)  female    15      1      0
# 1302                     Youseff, Mr. Gerious    male  45,5      0      0
# 1303                        Yousif, Mr. Wazli    male            0      0
# 1304                    Yousseff, Mr. Gerious    male            0      0
# 1305                     Zabour, Miss. Hileni  female  14,5      1      0
# 1306                    Zabour, Miss. Thamine  female            1      0
# 1307                Zakarian, Mr. Mapriededer    male  26,5      0      0
# 1308                      Zakarian, Mr. Ortin    male    27      0      0
# 1309                       Zimmerman, Mr. Leo    male    29      0      0
#
# 0     ticket     fare
# 1300    2659  14,4542
# 1301    2659  14,4542
# 1302    2628    7,225
# 1303    2647    7,225
# 1304    2627  14,4583
# 1305    2665  14,4542
# 1306    2665  14,4542
# 1307    2656    7,225
# 1308    2670    7,225
# 1309  315082    7,875

# %%
# Indexamos por etiqueta
df.loc[:,"name":'fare'] # Rango de columnas
# Out:
# 0                                                name     sex     age  sibsp  \
# 1                       Allen, Miss. Elisabeth Walton  female      29      0
# 2                      Allison, Master. Hudson Trevor    male  0,9167      1
# 3                        Allison, Miss. Helen Loraine  female       2      1
# 4                Allison, Mr. Hudson Joshua Creighton    male      30      1
# 5     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      25      1
# ...                                               ...     ...     ...    ...
# 1305                             Zabour, Miss. Hileni  female    14,5      1
# 1306                            Zabour, Miss. Thamine  female              1
# 1307                        Zakarian, Mr. Mapriededer    male    26,5      0
# 1308                              Zakarian, Mr. Ortin    male      27      0
# 1309                               Zimmerman, Mr. Leo    male      29      0
#
# 0     parch  ticket      fare
# 1         0   24160  211,3375
# 2         2  113781    151,55
# 3         2  113781    151,55
# 4         2  113781    151,55
# 5         2  113781    151,55
# ...     ...     ...       ...
# 1305      0    2665   14,4542
# 1306      0    2665   14,4542
# 1307      0    2656     7,225
# 1308      0    2670     7,225
# 1309      0  315082     7,875
#
# [1309 rows x 7 columns]

# %% [markdown]
# **Filtros**

# %%
# Filtrar una categoría
df[df['sex']=='female']
# Out:
# 0     pclass  survived                                             name  \
# 1          1         1                    Allen, Miss. Elisabeth Walton
# 3          1         0                     Allison, Miss. Helen Loraine
# 5          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7          1         1                Andrews, Miss. Kornelia Theodosia
# 9          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1287       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1291       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1301       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1305       3         0                             Zabour, Miss. Hileni
# 1306       3         0                            Zabour, Miss. Thamine
#
# 0        sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 1     female    29      0      0   24160  211,3375       B5        S    2
# 3     female     2      1      2  113781    151,55  C22 C26        S
# 5     female    25      1      2  113781    151,55  C22 C26        S
# 7     female    63      1      0   13502   77,9583       D7        S   10
# 9     female    53      2      0   11769   51,4792     C101        S    D
# ...      ...   ...    ...    ...     ...       ...      ...      ...  ...
# 1287  female    38      0      0    2688    7,2292                 C    C
# 1291  female    47      1      0  363272         7                 S
# 1301  female    15      1      0    2659   14,4542                 C
# 1305  female  14,5      1      0    2665   14,4542                 C
# 1306  female            1      0    2665   14,4542                 C
#
# 0      body                        home.dest
# 1       NaN                     St Louis, MO
# 3       NaN  Montreal, PQ / Chesterville, ON
# 5       NaN  Montreal, PQ / Chesterville, ON
# 7       NaN                       Hudson, NY
# 9       NaN              Bayside, Queens, NY
# ...     ...                              ...
# 1287    NaN
# 1291    NaN
# 1301    NaN
# 1305  328.0
# 1306    NaN
#
# [466 rows x 14 columns]

# %%
# Filtrar por umbral columnas numéricas
df[df['sibsp']>0]
# Out:
# 0     pclass  survived                                             name  \
# 2          1         1                   Allison, Master. Hudson Trevor
# 3          1         0                     Allison, Miss. Helen Loraine
# 4          1         0             Allison, Mr. Hudson Joshua Creighton
# 5          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7          1         1                Andrews, Miss. Kornelia Theodosia
# ...      ...       ...                                              ...
# 1291       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         0                              Yasbeck, Mr. Antoni
# 1301       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1305       3         0                             Zabour, Miss. Hileni
# 1306       3         0                            Zabour, Miss. Thamine
#
# 0        sex     age  sibsp  parch  ticket     fare    cabin embarked boat  \
# 2       male  0,9167      1      2  113781   151,55  C22 C26        S   11
# 3     female       2      1      2  113781   151,55  C22 C26        S
# 4       male      30      1      2  113781   151,55  C22 C26        S
# 5     female      25      1      2  113781   151,55  C22 C26        S
# 7     female      63      1      0   13502  77,9583       D7        S   10
# ...      ...     ...    ...    ...     ...      ...      ...      ...  ...
# 1291  female      47      1      0  363272        7                 S
# 1300    male      27      1      0    2659  14,4542                 C    C
# 1301  female      15      1      0    2659  14,4542                 C
# 1305  female    14,5      1      0    2665  14,4542                 C
# 1306  female              1      0    2665  14,4542                 C
#
# 0      body                        home.dest
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3       NaN  Montreal, PQ / Chesterville, ON
# 4     135.0  Montreal, PQ / Chesterville, ON
# 5       NaN  Montreal, PQ / Chesterville, ON
# 7       NaN                       Hudson, NY
# ...     ...                              ...
# 1291    NaN
# 1300    NaN
# 1301    NaN
# 1305  328.0
# 1306    NaN
#
# [418 rows x 14 columns]

# %%
# Filtrar por rango
df[df['sibsp'].between(2,4)] # Equivalente a hacer df[(df['sibsp']>=2) & (df['sibsp']<=4)]
# Out:
# 0     pclass  survived                                               name  \
# 9          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 43         1         1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 80         1         1  Cornell, Mrs. Robert Clifford (Malvina Helen L...
# 112        1         1                     Fortune, Miss. Alice Elizabeth
# 113        1         1                         Fortune, Miss. Ethel Flora
# ...      ...       ...                                                ...
# 1209       3         0                                 Skoog, Miss. Mabel
# 1210       3         0                      Skoog, Miss. Margit Elizabeth
# 1274       3         0                 Vander Planke, Miss. Augusta Maria
# 1275       3         0                          Vander Planke, Mr. Julius
# 1276       3         0                    Vander Planke, Mr. Leo Edmondus
#
# 0        sex age  sibsp  parch  ticket     fare        cabin embarked boat  \
# 9     female  53      2      0   11769  51,4792         C101        S    D
# 43    female  59      2      0   11769  51,4792         C101        S    D
# 80    female  55      2      0   11770     25,7         C101        S    2
# 112   female  24      3      2   19950      263  C23 C25 C27        S   10
# 113   female  28      3      2   19950      263  C23 C25 C27        S   10
# ...      ...  ..    ...    ...     ...      ...          ...      ...  ...
# 1209  female   9      3      2  347088     27,9                     S
# 1210  female   2      3      2  347088     27,9                     S
# 1274  female  18      2      0  345764       18                     S
# 1275    male  31      3      0  345763       18                     S
# 1276    male  16      2      0  345764       18                     S
#
# 0     body            home.dest
# 9      NaN  Bayside, Queens, NY
# 43     NaN          Belmont, MA
# 80     NaN         New York, NY
# 112    NaN         Winnipeg, MB
# 113    NaN         Winnipeg, MB
# ...    ...                  ...
# 1209   NaN
# 1210   NaN
# 1274   NaN
# 1275   NaN
# 1276   NaN
#
# [84 rows x 14 columns]

# %%
# Filtrar por un percentil
df[ df['sibsp'] >= df['sibsp'].quantile(0.95)]
# Out:
# 0     pclass  survived                                               name  \
# 9          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 43         1         1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 80         1         1  Cornell, Mrs. Robert Clifford (Malvina Helen L...
# 112        1         1                     Fortune, Miss. Alice Elizabeth
# 113        1         1                         Fortune, Miss. Ethel Flora
# ...      ...       ...                                                ...
# 1209       3         0                                 Skoog, Miss. Mabel
# 1210       3         0                      Skoog, Miss. Margit Elizabeth
# 1274       3         0                 Vander Planke, Miss. Augusta Maria
# 1275       3         0                          Vander Planke, Mr. Julius
# 1276       3         0                    Vander Planke, Mr. Leo Edmondus
#
# 0        sex age  sibsp  parch  ticket     fare        cabin embarked boat  \
# 9     female  53      2      0   11769  51,4792         C101        S    D
# 43    female  59      2      0   11769  51,4792         C101        S    D
# 80    female  55      2      0   11770     25,7         C101        S    2
# 112   female  24      3      2   19950      263  C23 C25 C27        S   10
# 113   female  28      3      2   19950      263  C23 C25 C27        S   10
# ...      ...  ..    ...    ...     ...      ...          ...      ...  ...
# 1209  female   9      3      2  347088     27,9                     S
# 1210  female   2      3      2  347088     27,9                     S
# 1274  female  18      2      0  345764       18                     S
# 1275    male  31      3      0  345763       18                     S
# 1276    male  16      2      0  345764       18                     S
#
# 0     body            home.dest
# 9      NaN  Bayside, Queens, NY
# 43     NaN          Belmont, MA
# 80     NaN         New York, NY
# 112    NaN         Winnipeg, MB
# 113    NaN         Winnipeg, MB
# ...    ...                  ...
# 1209   NaN
# 1210   NaN
# 1274   NaN
# 1275   NaN
# 1276   NaN
#
# [99 rows x 14 columns]

# %%
# Filtrar con & (and) y | (or)
df[(df['survived']==1) & (df['pclass']==3)]
# Out:
# 0     pclass  survived                                             name  \
# 604        3         1                 Abbott, Mrs. Stanton (Rosa Hunt)
# 605        3         1                      Abelseth, Miss. Karen Marie
# 606        3         1                    Abelseth, Mr. Olaus Jorgensen
# 607        3         1         Abrahamsson, Mr. Abraham August Johannes
# 608        3         1        Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# ...      ...       ...                                              ...
# 1262       3         1                           Turkula, Mrs. (Hedwig)
# 1278       3         1                             Vartanian, Mr. David
# 1287       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1291       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1301       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
# 0        sex age  sibsp  parch            ticket     fare  cabin embarked  \
# 604   female  35      1      1         C.A. 2673    20,25               S
# 605   female  16      0      0            348125     7,65               S
# 606     male  25      0      0            348122     7,65  F G63        S
# 607     male  20      0      0  SOTON/O2 3101284    7,925               S
# 608   female  18      0      0              2657   7,2292               C
# ...      ...  ..    ...    ...               ...      ...    ...      ...
# 1262  female  63      0      0              4134   9,5875               S
# 1278    male  22      0      0              2658    7,225               C
# 1287  female  38      0      0              2688   7,2292               C
# 1291  female  47      1      0            363272        7               S
# 1301  female  15      1      0              2659  14,4542               C
#
# 0      boat  body                          home.dest
# 604       A   NaN                East Providence, RI
# 605      16   NaN             Norway Los Angeles, CA
# 606       A   NaN                 Perkins County, SD
# 607      15   NaN  Taalintehdas, Finland Hoboken, NJ
# 608       C   NaN                     Greensburg, PA
# ...     ...   ...                                ...
# 1262     15   NaN
# 1278  13 15   NaN
# 1287      C   NaN
# 1291          NaN
# 1301          NaN
#
# [181 rows x 14 columns]

# %%
# Filtrar por un substring
df[df['name'].str.lower().str.contains('allison')] # el .str hace referencia a que el valor es un string y el .lower() hace lowercase a todo el string.
# Out:
# 0  pclass  survived                                             name     sex  \
# 2       1         1                   Allison, Master. Hudson Trevor    male
# 3       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 5       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
# 0     age  sibsp  parch  ticket    fare    cabin embarked boat   body  \
# 2  0,9167      1      2  113781  151,55  C22 C26        S   11    NaN
# 3       2      1      2  113781  151,55  C22 C26        S         NaN
# 4      30      1      2  113781  151,55  C22 C26        S       135.0
# 5      25      1      2  113781  151,55  C22 C26        S         NaN
#
# 0                        home.dest
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5  Montreal, PQ / Chesterville, ON

# %% [markdown]
# **Ordenar**

# %%
df.sort_values(['pclass','sibsp'], ascending=False, inplace=True)
df
# Out:
# 0     pclass  survived                                    name     sex   age  \
# 1171       3         0              Sage, Master. Thomas Henry    male
# 1172       3         0             Sage, Master. William Henry    male  14,5
# 1173       3         0                         Sage, Miss. Ada  female
# 1174       3         0            Sage, Miss. Constance Gladys  female
# 1175       3         0       Sage, Miss. Dorothy Edith "Dolly"  female
# ...      ...       ...                                     ...     ...   ...
# 319        1         0  Williams-Lambert, Mr. Fletcher Fellows    male
# 320        1         1               Wilson, Miss. Helen Alice  female    31
# 321        1         1                       Woolner, Mr. Hugh    male
# 322        1         0                      Wright, Mr. George    male    62
# 323        1         1                Young, Miss. Marie Grice  female    36
#
# 0     sibsp  parch    ticket      fare    cabin embarked boat  body  \
# 1171      8      2  CA. 2343     69,55                 S        NaN
# 1172      8      2  CA. 2343     69,55                 S       67.0
# 1173      8      2  CA. 2343     69,55                 S        NaN
# 1174      8      2  CA. 2343     69,55                 S        NaN
# 1175      8      2  CA. 2343     69,55                 S        NaN
# ...     ...    ...       ...       ...      ...      ...  ...   ...
# 319       0      0    113510        35     C128        S        NaN
# 320       0      0     16966     134,5  E39 E41        C    3   NaN
# 321       0      0     19947      35,5      C52        S    D   NaN
# 322       0      0    113807     26,55                 S        NaN
# 323       0      0  PC 17760  135,6333      C32        C    8   NaN
#
# 0                         home.dest
# 1171
# 1172
# 1173
# 1174
# 1175
# ...                             ...
# 319                 London, England
# 320
# 321                 London, England
# 322                     Halifax, NS
# 323   New York, NY / Washington, DC
#
# [1309 rows x 14 columns]

# %% [markdown]
# ---
#
#
# #### **Transformar Datos**
#
#
# ---

# %%
df.dtypes
# Out:
# 0
# pclass         int64
# survived       int64
# name          object
# sex           object
# age           object
# sibsp          int64
# parch          int64
# ticket        object
# fare          object
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
# Vemos que hay casos de 'age' con espacios (nulos escondidos)
df[df['age']=='']
# Out:
# 0     pclass  survived                                    name     sex age  \
# 1171       3         0              Sage, Master. Thomas Henry    male
# 1173       3         0                         Sage, Miss. Ada  female
# 1174       3         0            Sage, Miss. Constance Gladys  female
# 1175       3         0       Sage, Miss. Dorothy Edith "Dolly"  female
# 1176       3         0                 Sage, Miss. Stella Anna  female
# ...      ...       ...                                     ...     ...  ..
# 270        1         0              Smith, Mr. Richard William    male
# 284        1         0                   Stewart, Mr. Albert A    male
# 298        1         1          Thorne, Mrs. Gertrude Maybelle  female
# 319        1         0  Williams-Lambert, Mr. Fletcher Fellows    male
# 321        1         1                       Woolner, Mr. Hugh    male
#
# 0     sibsp  parch    ticket     fare cabin embarked boat  body  \
# 1171      8      2  CA. 2343    69,55              S        NaN
# 1173      8      2  CA. 2343    69,55              S        NaN
# 1174      8      2  CA. 2343    69,55              S        NaN
# 1175      8      2  CA. 2343    69,55              S        NaN
# 1176      8      2  CA. 2343    69,55              S        NaN
# ...     ...    ...       ...      ...   ...      ...  ...   ...
# 270       0      0    113056       26   A19        S        NaN
# 284       0      0  PC 17605  27,7208              C        NaN
# 298       0      0  PC 17585     79,2              C    D   NaN
# 319       0      0    113510       35  C128        S        NaN
# 321       0      0     19947     35,5   C52        S    D   NaN
#
# 0                                 home.dest
# 1171
# 1173
# 1174
# 1175
# 1176
# ...                                     ...
# 270                       Streatham, Surrey
# 284   Gallipolis, Ohio / ? Paris / New York
# 298                            New York, NY
# 319                         London, England
# 321                         London, England
#
# [263 rows x 14 columns]

# %% [markdown]
# **Transformo condicionalmente**

# %%
# Modifico age con espacios
df['age'] = np.where(df['age']=='',np.nan, df['age'])  # similar al if: np.where(condición, resultado true, resultado false)
df['age'].count() # chequeamos los nulos ahora
# Out:
# 1046

# %%
# Armo el feature viaja_solo
df['viaja_solo'] = np.where((df['sibsp']>0) | (df['parch']>0),0,1)  # np.where(condicion/es,resultado si verdadero, resultado si falso)
df
# Out:
# 0     pclass  survived                                    name     sex   age  \
# 1171       3         0              Sage, Master. Thomas Henry    male   NaN
# 1172       3         0             Sage, Master. William Henry    male  14,5
# 1173       3         0                         Sage, Miss. Ada  female   NaN
# 1174       3         0            Sage, Miss. Constance Gladys  female   NaN
# 1175       3         0       Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# ...      ...       ...                                     ...     ...   ...
# 319        1         0  Williams-Lambert, Mr. Fletcher Fellows    male   NaN
# 320        1         1               Wilson, Miss. Helen Alice  female    31
# 321        1         1                       Woolner, Mr. Hugh    male   NaN
# 322        1         0                      Wright, Mr. George    male    62
# 323        1         1                Young, Miss. Marie Grice  female    36
#
# 0     sibsp  parch    ticket      fare    cabin embarked boat  body  \
# 1171      8      2  CA. 2343     69,55                 S        NaN
# 1172      8      2  CA. 2343     69,55                 S       67.0
# 1173      8      2  CA. 2343     69,55                 S        NaN
# 1174      8      2  CA. 2343     69,55                 S        NaN
# 1175      8      2  CA. 2343     69,55                 S        NaN
# ...     ...    ...       ...       ...      ...      ...  ...   ...
# 319       0      0    113510        35     C128        S        NaN
# 320       0      0     16966     134,5  E39 E41        C    3   NaN
# 321       0      0     19947      35,5      C52        S    D   NaN
# 322       0      0    113807     26,55                 S        NaN
# 323       0      0  PC 17760  135,6333      C32        C    8   NaN
#
# 0                         home.dest  viaja_solo
# 1171                                          0
# 1172                                          0
# 1173                                          0
# 1174                                          0
# 1175                                          0
# ...                             ...         ...
# 319                 London, England           1
# 320                                           1
# 321                 London, England           1
# 322                     Halifax, NS           1
# 323   New York, NY / Washington, DC           1
#
# [1309 rows x 15 columns]

# %%
# Uso casos (como un if anidado): Armo rango_etario
conditions = [df['age']<13, df['age']<20, df['age']<60,df['age']<110]
choices = ["niño",'adolescente','adulto','anciano']

df['rango_etario'] = np.select(conditions, choices, default=np.nan)  # Si no lo encuentra es nan
df
# Out:
# 0     pclass  survived                                    name     sex   age  \
# 1171       3         0              Sage, Master. Thomas Henry    male   NaN
# 1172       3         0             Sage, Master. William Henry    male  14.5
# 1173       3         0                         Sage, Miss. Ada  female   NaN
# 1174       3         0            Sage, Miss. Constance Gladys  female   NaN
# 1175       3         0       Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# ...      ...       ...                                     ...     ...   ...
# 319        1         0  Williams-Lambert, Mr. Fletcher Fellows    male   NaN
# 320        1         1               Wilson, Miss. Helen Alice  female  31.0
# 321        1         1                       Woolner, Mr. Hugh    male   NaN
# 322        1         0                      Wright, Mr. George    male  62.0
# 323        1         1                Young, Miss. Marie Grice  female  36.0
#
# 0     sibsp  parch    ticket      fare    cabin embarked boat  body  \
# 1171      8      2  CA. 2343     69,55                 S        NaN
# 1172      8      2  CA. 2343     69,55                 S       67.0
# 1173      8      2  CA. 2343     69,55                 S        NaN
# 1174      8      2  CA. 2343     69,55                 S        NaN
# 1175      8      2  CA. 2343     69,55                 S        NaN
# ...     ...    ...       ...       ...      ...      ...  ...   ...
# 319       0      0    113510        35     C128        S        NaN
# 320       0      0     16966     134,5  E39 E41        C    3   NaN
# 321       0      0     19947      35,5      C52        S    D   NaN
# 322       0      0    113807     26,55                 S        NaN
# 323       0      0  PC 17760  135,6333      C32        C    8   NaN
#
# 0                         home.dest  viaja_solo rango_etario
# 1171                                          0          nan
# 1172                                          0  adolescente
# 1173                                          0          nan
# 1174                                          0          nan
# 1175                                          0          nan
# ...                             ...         ...          ...
# 319                 London, England           1          nan
# 320                                           1       adulto
# 321                 London, England           1          nan
# 322                     Halifax, NS           1      anciano
# 323   New York, NY / Washington, DC           1       adulto
#
# [1309 rows x 16 columns]

# %%
df[df['age']<30] # ups!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-276e5a13af42> in <cell line: 1>()
# ----> 1 df[df['age']<30] # ups!
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      79         other = item_from_zerodim(other)
#      80
# ---> 81         return method(self, other)
#      82
#      83     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __lt__(self, other)
#      46     @unpack_zerodim_and_defer("__lt__")
#      47     def __lt__(self, other):
# ---> 48         return self._cmp_method(other, operator.lt)
#      49
#      50     @unpack_zerodim_and_defer("__le__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6094
#    6095         with np.errstate(all="ignore"):
# -> 6096             res_values = ops.comparison_op(lvalues, rvalues, op)
#    6097
#    6098         return self._construct_result(res_values, name=res_name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     291
#     292     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 293         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     294
#     295     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      80         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      81     else:
# ---> 82         result = libops.scalar_compare(x.ravel(), y, op)
#      83     return result.reshape(x.shape)
#      84
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# **Transformo strings**

# %%
# Cambiamos , por . para que pueda leerlo como numérico
df['age'] = df['age'].apply(lambda x: str(x).replace(',','.')) # Famosa función lambda

# Cambiamos de tipo 'age'
df['age'] = df['age'].astype(float)

df.dtypes
# Out:
# 0
# pclass          int64
# survived        int64
# name           object
# sex            object
# age           float64
# sibsp           int64
# parch           int64
# ticket         object
# fare           object
# cabin          object
# embarked       object
# boat           object
# body          float64
# home.dest      object
# viaja_solo      int64
# dtype: object

# %%
# Cambiamos el nombre de la columna name a name_raw
df.rename(columns={'name':'name_raw'},inplace=True) # Se puede especificar más cambios dentro de las llaves

# Creamos una variable de Apellido y Nombre
df['last_name'] = df['name_raw'].apply(lambda x: x.split(',')[0])  # Tomo el campo nombre y divido por la ',', me quedo con la primera parte
df['name'] = df['name_raw'].apply(lambda x: x.split(',')[1]) # Tomo el campo nombre y divido por la ',', mequedo con la segunda parte y piso la columna 'name'
df
# Out:
# 0     pclass  survived                                name_raw     sex   age  \
# 1171       3         0              Sage, Master. Thomas Henry    male   NaN
# 1172       3         0             Sage, Master. William Henry    male  14.5
# 1173       3         0                         Sage, Miss. Ada  female   NaN
# 1174       3         0            Sage, Miss. Constance Gladys  female   NaN
# 1175       3         0       Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# ...      ...       ...                                     ...     ...   ...
# 319        1         0  Williams-Lambert, Mr. Fletcher Fellows    male   NaN
# 320        1         1               Wilson, Miss. Helen Alice  female  31.0
# 321        1         1                       Woolner, Mr. Hugh    male   NaN
# 322        1         0                      Wright, Mr. George    male  62.0
# 323        1         1                Young, Miss. Marie Grice  female  36.0
#
# 0     sibsp  parch    ticket      fare    cabin embarked boat  body  \
# 1171      8      2  CA. 2343     69,55                 S        NaN
# 1172      8      2  CA. 2343     69,55                 S       67.0
# 1173      8      2  CA. 2343     69,55                 S        NaN
# 1174      8      2  CA. 2343     69,55                 S        NaN
# 1175      8      2  CA. 2343     69,55                 S        NaN
# ...     ...    ...       ...       ...      ...      ...  ...   ...
# 319       0      0    113510        35     C128        S        NaN
# 320       0      0     16966     134,5  E39 E41        C    3   NaN
# 321       0      0     19947      35,5      C52        S    D   NaN
# 322       0      0    113807     26,55                 S        NaN
# 323       0      0  PC 17760  135,6333      C32        C    8   NaN
#
# 0                         home.dest  viaja_solo rango_etario  \
# 1171                                          0          nan
# 1172                                          0  adolescente
# 1173                                          0          nan
# 1174                                          0          nan
# 1175                                          0          nan
# ...                             ...         ...          ...
# 319                 London, England           1          nan
# 320                                           1       adulto
# 321                 London, England           1          nan
# 322                     Halifax, NS           1      anciano
# 323   New York, NY / Washington, DC           1       adulto
#
# 0            last_name                          name
# 1171              Sage          Master. Thomas Henry
# 1172              Sage         Master. William Henry
# 1173              Sage                     Miss. Ada
# 1174              Sage        Miss. Constance Gladys
# 1175              Sage   Miss. Dorothy Edith "Dolly"
# ...                ...                           ...
# 319   Williams-Lambert          Mr. Fletcher Fellows
# 320             Wilson             Miss. Helen Alice
# 321            Woolner                      Mr. Hugh
# 322             Wright                    Mr. George
# 323              Young             Miss. Marie Grice
#
# [1309 rows x 18 columns]

# %%
# Separo la variable Titulo Familiar:
df['title'] = df['name'].apply(lambda x: x.split('.')[0]) # Creo el título
df['name'] = df['name'].apply(lambda x: x.split('.')[1])  # Piso el nombre
df
# Out:
# 0     pclass  survived                                name_raw     sex   age  \
# 1171       3         0              Sage, Master. Thomas Henry    male   NaN
# 1172       3         0             Sage, Master. William Henry    male  14.5
# 1173       3         0                         Sage, Miss. Ada  female   NaN
# 1174       3         0            Sage, Miss. Constance Gladys  female   NaN
# 1175       3         0       Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# ...      ...       ...                                     ...     ...   ...
# 319        1         0  Williams-Lambert, Mr. Fletcher Fellows    male   NaN
# 320        1         1               Wilson, Miss. Helen Alice  female  31.0
# 321        1         1                       Woolner, Mr. Hugh    male   NaN
# 322        1         0                      Wright, Mr. George    male  62.0
# 323        1         1                Young, Miss. Marie Grice  female  36.0
#
# 0     sibsp  parch    ticket      fare    cabin embarked boat  body  \
# 1171      8      2  CA. 2343     69,55                 S        NaN
# 1172      8      2  CA. 2343     69,55                 S       67.0
# 1173      8      2  CA. 2343     69,55                 S        NaN
# 1174      8      2  CA. 2343     69,55                 S        NaN
# 1175      8      2  CA. 2343     69,55                 S        NaN
# ...     ...    ...       ...       ...      ...      ...  ...   ...
# 319       0      0    113510        35     C128        S        NaN
# 320       0      0     16966     134,5  E39 E41        C    3   NaN
# 321       0      0     19947      35,5      C52        S    D   NaN
# 322       0      0    113807     26,55                 S        NaN
# 323       0      0  PC 17760  135,6333      C32        C    8   NaN
#
# 0                         home.dest  viaja_solo rango_etario  \
# 1171                                          0          nan
# 1172                                          0  adolescente
# 1173                                          0          nan
# 1174                                          0          nan
# 1175                                          0          nan
# ...                             ...         ...          ...
# 319                 London, England           1          nan
# 320                                           1       adulto
# 321                 London, England           1          nan
# 322                     Halifax, NS           1      anciano
# 323   New York, NY / Washington, DC           1       adulto
#
# 0            last_name                    name    title
# 1171              Sage            Thomas Henry   Master
# 1172              Sage           William Henry   Master
# 1173              Sage                     Ada     Miss
# 1174              Sage        Constance Gladys     Miss
# 1175              Sage   Dorothy Edith "Dolly"     Miss
# ...                ...                     ...      ...
# 319   Williams-Lambert        Fletcher Fellows       Mr
# 320             Wilson             Helen Alice     Miss
# 321            Woolner                    Hugh       Mr
# 322             Wright                  George       Mr
# 323              Young             Marie Grice     Miss
#
# [1309 rows x 19 columns]

# %%
# Cortamos un string: primeras 3 letras del apellido
df['mini_last_name'] = df['last_name'].apply(lambda x: str(x)[0:3])
df
# Out:
# 0     pclass  survived                                name_raw     sex   age  \
# 1171       3         0              Sage, Master. Thomas Henry    male   NaN
# 1172       3         0             Sage, Master. William Henry    male  14.5
# 1173       3         0                         Sage, Miss. Ada  female   NaN
# 1174       3         0            Sage, Miss. Constance Gladys  female   NaN
# 1175       3         0       Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# ...      ...       ...                                     ...     ...   ...
# 319        1         0  Williams-Lambert, Mr. Fletcher Fellows    male   NaN
# 320        1         1               Wilson, Miss. Helen Alice  female  31.0
# 321        1         1                       Woolner, Mr. Hugh    male   NaN
# 322        1         0                      Wright, Mr. George    male  62.0
# 323        1         1                Young, Miss. Marie Grice  female  36.0
#
# 0     sibsp  parch    ticket      fare    cabin embarked boat  body  \
# 1171      8      2  CA. 2343     69,55                 S        NaN
# 1172      8      2  CA. 2343     69,55                 S       67.0
# 1173      8      2  CA. 2343     69,55                 S        NaN
# 1174      8      2  CA. 2343     69,55                 S        NaN
# 1175      8      2  CA. 2343     69,55                 S        NaN
# ...     ...    ...       ...       ...      ...      ...  ...   ...
# 319       0      0    113510        35     C128        S        NaN
# 320       0      0     16966     134,5  E39 E41        C    3   NaN
# 321       0      0     19947      35,5      C52        S    D   NaN
# 322       0      0    113807     26,55                 S        NaN
# 323       0      0  PC 17760  135,6333      C32        C    8   NaN
#
# 0                         home.dest  viaja_solo rango_etario  \
# 1171                                          0          nan
# 1172                                          0  adolescente
# 1173                                          0          nan
# 1174                                          0          nan
# 1175                                          0          nan
# ...                             ...         ...          ...
# 319                 London, England           1          nan
# 320                                           1       adulto
# 321                 London, England           1          nan
# 322                     Halifax, NS           1      anciano
# 323   New York, NY / Washington, DC           1       adulto
#
# 0            last_name                    name    title mini_last_name
# 1171              Sage            Thomas Henry   Master            Sag
# 1172              Sage           William Henry   Master            Sag
# 1173              Sage                     Ada     Miss            Sag
# 1174              Sage        Constance Gladys     Miss            Sag
# 1175              Sage   Dorothy Edith "Dolly"     Miss            Sag
# ...                ...                     ...      ...            ...
# 319   Williams-Lambert        Fletcher Fellows       Mr            Wil
# 320             Wilson             Helen Alice     Miss            Wil
# 321            Woolner                    Hugh       Mr            Woo
# 322             Wright                  George       Mr            Wri
# 323              Young             Marie Grice     Miss            You
#
# [1309 rows x 20 columns]

# %% [markdown]
# **Opero con columnas**

# %%
# Operar con columnas: Sumo sibsp y	parch
df['n_familiares'] = df['sibsp'] + df['parch']
df
# Out:
# 0     pclass  survived                                name_raw     sex   age  \
# 1171       3         0              Sage, Master. Thomas Henry    male   NaN
# 1172       3         0             Sage, Master. William Henry    male  14.5
# 1173       3         0                         Sage, Miss. Ada  female   NaN
# 1174       3         0            Sage, Miss. Constance Gladys  female   NaN
# 1175       3         0       Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# ...      ...       ...                                     ...     ...   ...
# 319        1         0  Williams-Lambert, Mr. Fletcher Fellows    male   NaN
# 320        1         1               Wilson, Miss. Helen Alice  female  31.0
# 321        1         1                       Woolner, Mr. Hugh    male   NaN
# 322        1         0                      Wright, Mr. George    male  62.0
# 323        1         1                Young, Miss. Marie Grice  female  36.0
#
# 0     sibsp  parch    ticket      fare    cabin  ... boat  body  \
# 1171      8      2  CA. 2343     69,55           ...        NaN
# 1172      8      2  CA. 2343     69,55           ...       67.0
# 1173      8      2  CA. 2343     69,55           ...        NaN
# 1174      8      2  CA. 2343     69,55           ...        NaN
# 1175      8      2  CA. 2343     69,55           ...        NaN
# ...     ...    ...       ...       ...      ...  ...  ...   ...
# 319       0      0    113510        35     C128  ...        NaN
# 320       0      0     16966     134,5  E39 E41  ...    3   NaN
# 321       0      0     19947      35,5      C52  ...    D   NaN
# 322       0      0    113807     26,55           ...        NaN
# 323       0      0  PC 17760  135,6333      C32  ...    8   NaN
#
# 0                         home.dest viaja_solo  rango_etario  \
# 1171                                         0           nan
# 1172                                         0   adolescente
# 1173                                         0           nan
# 1174                                         0           nan
# 1175                                         0           nan
# ...                             ...        ...           ...
# 319                 London, England          1           nan
# 320                                          1        adulto
# 321                 London, England          1           nan
# 322                     Halifax, NS          1       anciano
# 323   New York, NY / Washington, DC          1        adulto
#
# 0            last_name                    name    title mini_last_name  \
# 1171              Sage            Thomas Henry   Master            Sag
# 1172              Sage           William Henry   Master            Sag
# 1173              Sage                     Ada     Miss            Sag
# 1174              Sage        Constance Gladys     Miss            Sag
# 1175              Sage   Dorothy Edith "Dolly"     Miss            Sag
# ...                ...                     ...      ...            ...
# 319   Williams-Lambert        Fletcher Fellows       Mr            Wil
# 320             Wilson             Helen Alice     Miss            Wil
# 321            Woolner                    Hugh       Mr            Woo
# 322             Wright                  George       Mr            Wri
# 323              Young             Marie Grice     Miss            You
#
# 0    n_familiares
# 1171           10
# 1172           10
# 1173           10
# 1174           10
# 1175           10
# ...           ...
# 319             0
# 320             0
# 321             0
# 322             0
# 323             0
#
# [1309 rows x 21 columns]

# %% [markdown]
# **Borro Columnas**

# %%
# Borro columnas
df.drop(['body','cabin','home.dest'], axis=1, inplace=True) # No hace falta poner el igual, ya que se aplica al mismo dataframe.
df
# Out:
# 0     pclass  survived                                name_raw     sex   age  \
# 1171       3         0              Sage, Master. Thomas Henry    male   NaN
# 1172       3         0             Sage, Master. William Henry    male  14.5
# 1173       3         0                         Sage, Miss. Ada  female   NaN
# 1174       3         0            Sage, Miss. Constance Gladys  female   NaN
# 1175       3         0       Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# ...      ...       ...                                     ...     ...   ...
# 319        1         0  Williams-Lambert, Mr. Fletcher Fellows    male   NaN
# 320        1         1               Wilson, Miss. Helen Alice  female  31.0
# 321        1         1                       Woolner, Mr. Hugh    male   NaN
# 322        1         0                      Wright, Mr. George    male  62.0
# 323        1         1                Young, Miss. Marie Grice  female  36.0
#
# 0     sibsp  parch    ticket      fare embarked boat  viaja_solo rango_etario  \
# 1171      8      2  CA. 2343     69,55        S                0          nan
# 1172      8      2  CA. 2343     69,55        S                0  adolescente
# 1173      8      2  CA. 2343     69,55        S                0          nan
# 1174      8      2  CA. 2343     69,55        S                0          nan
# 1175      8      2  CA. 2343     69,55        S                0          nan
# ...     ...    ...       ...       ...      ...  ...         ...          ...
# 319       0      0    113510        35        S                1          nan
# 320       0      0     16966     134,5        C    3           1       adulto
# 321       0      0     19947      35,5        S    D           1          nan
# 322       0      0    113807     26,55        S                1      anciano
# 323       0      0  PC 17760  135,6333        C    8           1       adulto
#
# 0            last_name                    name    title mini_last_name  \
# 1171              Sage            Thomas Henry   Master            Sag
# 1172              Sage           William Henry   Master            Sag
# 1173              Sage                     Ada     Miss            Sag
# 1174              Sage        Constance Gladys     Miss            Sag
# 1175              Sage   Dorothy Edith "Dolly"     Miss            Sag
# ...                ...                     ...      ...            ...
# 319   Williams-Lambert        Fletcher Fellows       Mr            Wil
# 320             Wilson             Helen Alice     Miss            Wil
# 321            Woolner                    Hugh       Mr            Woo
# 322             Wright                  George       Mr            Wri
# 323              Young             Marie Grice     Miss            You
#
# 0     n_familiares
# 1171            10
# 1172            10
# 1173            10
# 1174            10
# 1175            10
# ...            ...
# 319              0
# 320              0
# 321              0
# 322              0
# 323              0
#
# [1309 rows x 18 columns]

# %% [markdown]
# **Soluciono NAs**

# %%
# Quitar Na:
df_sin_na = df.dropna(how='any')  # El 'any' hace referencia a si tiene al menos una columna Na, la quita
                                  # Otra opción, es ponerle 'all' que saca la fila si tiene todo Na
print("Shape Original: ",df.shape, " Shape Nuevo: ", df_sin_na.shape)
# Out:
# Shape Original:  (1309, 18)  Shape Nuevo:  (1046, 18)

# %%
# Imputar los Na con 0:
df_imputado = df.fillna(0) # También tiene el campo inplace
print("Shape Original: ",df.shape, " Shape Nuevo: ", df_imputado.shape)
# Out:
# Shape Original:  (1309, 18)  Shape Nuevo:  (1309, 18)

# %% [markdown]
# ---
#
#
# ### **Agrupar el Dataset**
#
#
# ---

# %%
# Estadísticos por grupo (describe transpuesto)
grouped_pclass_describe = round(df.groupby('pclass').describe().T,2)
grouped_pclass_describe
# Out:
# pclass                   1       2       3
# 0
# survived     count  323.00  277.00  709.00
#              mean     0.62    0.43    0.26
#              std      0.49    0.50    0.44
#              min      0.00    0.00    0.00
#              25%      0.00    0.00    0.00
#              50%      1.00    0.00    0.00
#              75%      1.00    1.00    1.00
#              max      1.00    1.00    1.00
# age          count  284.00  261.00  501.00
#              mean    39.16   29.51   24.82
#              std     14.55   13.64   11.96
#              min      0.92    0.67    0.17
#              25%     28.00   22.00   18.00
#              50%     39.00   29.00   24.00
#              75%     50.00   36.00   32.00
#              max     80.00   70.00   74.00
# sibsp        count  323.00  277.00  709.00
#              mean     0.44    0.39    0.57
#              std      0.61    0.59    1.30
#              min      0.00    0.00    0.00
#              25%      0.00    0.00    0.00
#              50%      0.00    0.00    0.00
#              75%      1.00    1.00    1.00
#              max      3.00    3.00    8.00
# parch        count  323.00  277.00  709.00
#              mean     0.37    0.37    0.40
#              std      0.72    0.69    0.98
#              min      0.00    0.00    0.00
#              25%      0.00    0.00    0.00
#              50%      0.00    0.00    0.00
#              75%      0.50    1.00    0.00
#              max      4.00    3.00    9.00
# viaja_solo   count  323.00  277.00  709.00
#              mean     0.50    0.57    0.67
#              std      0.50    0.50    0.47
#              min      0.00    0.00    0.00
#              25%      0.00    0.00    0.00
#              50%      0.00    1.00    1.00
#              75%      1.00    1.00    1.00
#              max      1.00    1.00    1.00
# n_familiares count  323.00  277.00  709.00
#              mean     0.80    0.76    0.97
#              std      1.06    1.03    1.92
#              min      0.00    0.00    0.00
#              25%      0.00    0.00    0.00
#              50%      1.00    0.00    0.00
#              75%      1.00    1.00    1.00
#              max      5.00    5.00   10.00

# %%
# Agrupamos por clase
grouped_pclass = df.groupby('pclass') # No trae nada
print(type(grouped_pclass))  # Es un objeto!
grouped_pclass
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
# Imprimimos las tablas del grupo
for names, groups in grouped_pclass:
  print(names) # El valor de la variable agrupadora
  print(groups) # La tabla que comparte ese valor de la variable agrupadora
# Out:
# 1
# 0    pclass  survived                                       name_raw     sex  \
# 112       1         1                 Fortune, Miss. Alice Elizabeth  female
# 113       1         1                     Fortune, Miss. Ethel Flora  female
# 114       1         1                     Fortune, Miss. Mabel Helen  female
# 115       1         0                 Fortune, Mr. Charles Alexander    male
# 9         1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# ..      ...       ...                                            ...     ...
# 319       1         0         Williams-Lambert, Mr. Fletcher Fellows    male
# 320       1         1                      Wilson, Miss. Helen Alice  female
# 321       1         1                              Woolner, Mr. Hugh    male
# 322       1         0                             Wright, Mr. George    male
# 323       1         1                       Young, Miss. Marie Grice  female
#
# 0     age  sibsp  parch    ticket      fare embarked boat  viaja_solo  \
# 112  24.0      3      2     19950       263        S   10           0
# 113  28.0      3      2     19950       263        S   10           0
# 114  23.0      3      2     19950       263        S   10           0
# 115  19.0      3      2     19950       263        S                0
# 9    53.0      2      0     11769   51,4792        S    D           0
# ..    ...    ...    ...       ...       ...      ...  ...         ...
# 319   NaN      0      0    113510        35        S                1
# 320  31.0      0      0     16966     134,5        C    3           1
# 321   NaN      0      0     19947      35,5        S    D           1
# 322  62.0      0      0    113807     26,55        S                1
# 323  36.0      0      0  PC 17760  135,6333        C    8           1
#
# 0   rango_etario         last_name                             name  title  \
# 112       adulto           Fortune                  Alice Elizabeth   Miss
# 113       adulto           Fortune                      Ethel Flora   Miss
# 114       adulto           Fortune                      Mabel Helen   Miss
# 115  adolescente           Fortune                Charles Alexander     Mr
# 9         adulto          Appleton   Edward Dale (Charlotte Lamson)    Mrs
# ..           ...               ...                              ...    ...
# 319          nan  Williams-Lambert                 Fletcher Fellows     Mr
# 320       adulto            Wilson                      Helen Alice   Miss
# 321          nan           Woolner                             Hugh     Mr
# 322      anciano            Wright                           George     Mr
# 323       adulto             Young                      Marie Grice   Miss
#
# 0   mini_last_name  n_familiares
# 112            For             5
# 113            For             5
# 114            For             5
# 115            For             5
# 9              App             2
# ..             ...           ...
# 319            Wil             0
# 320            Wil             0
# 321            Woo             0
# 322            Wri             0
# 323            You             0
#
# [323 rows x 18 columns]
# 2
# 0    pclass  survived                                     name_raw     sex  \
# 546       2         1  Renouf, Mrs. Peter Henry (Lillian Jefferys)  female
# 340       2         1                    Becker, Master. Richard F    male
# 341       2         1                  Becker, Miss. Marion Louise  female
# 342       2         1                 Becker, Miss. Ruth Elizabeth  female
# 443       2         0                    Hickman, Mr. Leonard Mark    male
# ..      ...       ...                                          ...     ...
# 596       2         0               Wheeler, Mr. Edwin "Frederick"    male
# 597       2         1                        Wilhelms, Mr. Charles    male
# 598       2         1                 Williams, Mr. Charles Eugene    male
# 599       2         1                         Wright, Miss. Marion  female
# 600       2         0       Yrois, Miss. Henriette ("Mrs Harbeck")  female
#
# 0     age  sibsp  parch         ticket    fare embarked boat  viaja_solo  \
# 546  30.0      3      0          31027      21        S                0
# 340   1.0      2      1         230136      39        S   11           0
# 341   4.0      2      1         230136      39        S   11           0
# 342  12.0      2      1         230136      39        S   13           0
# 443  24.0      2      0   S.O.C. 14879    73,5        S                0
# ..    ...    ...    ...            ...     ...      ...  ...         ...
# 596   NaN      0      0  SC/PARIS 2159  12,875        S                1
# 597  31.0      0      0         244270      13        S    9           1
# 598   NaN      0      0         244373      13        S   14           1
# 599  26.0      0      0         220844    13,5        S    9           1
# 600  24.0      0      0         248747      13        S                1
#
# 0   rango_etario last_name                             name    title  \
# 546       adulto    Renouf   Peter Henry (Lillian Jefferys)      Mrs
# 340         niño    Becker                        Richard F   Master
# 341         niño    Becker                    Marion Louise     Miss
# 342         niño    Becker                   Ruth Elizabeth     Miss
# 443       adulto   Hickman                     Leonard Mark       Mr
# ..           ...       ...                              ...      ...
# 596          nan   Wheeler                Edwin "Frederick"       Mr
# 597       adulto  Wilhelms                          Charles       Mr
# 598          nan  Williams                   Charles Eugene       Mr
# 599       adulto    Wright                           Marion     Miss
# 600       adulto     Yrois        Henriette ("Mrs Harbeck")     Miss
#
# 0   mini_last_name  n_familiares
# 546            Ren             3
# 340            Bec             3
# 341            Bec             3
# 342            Bec             3
# 443            Hic             2
# ..             ...           ...
# 596            Whe             0
# 597            Wil             0
# 598            Wil             0
# 599            Wri             0
# 600            Yro             0
#
# [277 rows x 18 columns]
# 3
# 0     pclass  survived                           name_raw     sex   age  \
# 1171       3         0         Sage, Master. Thomas Henry    male   NaN
# 1172       3         0        Sage, Master. William Henry    male  14.5
# 1173       3         0                    Sage, Miss. Ada  female   NaN
# 1174       3         0       Sage, Miss. Constance Gladys  female   NaN
# 1175       3         0  Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# ...      ...       ...                                ...     ...   ...
# 1303       3         0                  Yousif, Mr. Wazli    male   NaN
# 1304       3         0              Yousseff, Mr. Gerious    male   NaN
# 1307       3         0          Zakarian, Mr. Mapriededer    male  26.5
# 1308       3         0                Zakarian, Mr. Ortin    male  27.0
# 1309       3         0                 Zimmerman, Mr. Leo    male  29.0
#
# 0     sibsp  parch    ticket     fare embarked boat  viaja_solo rango_etario  \
# 1171      8      2  CA. 2343    69,55        S                0          nan
# 1172      8      2  CA. 2343    69,55        S                0  adolescente
# 1173      8      2  CA. 2343    69,55        S                0          nan
# 1174      8      2  CA. 2343    69,55        S                0          nan
# 1175      8      2  CA. 2343    69,55        S                0          nan
# ...     ...    ...       ...      ...      ...  ...         ...          ...
# 1303      0      0      2647    7,225        C                1          nan
# 1304      0      0      2627  14,4583        C                1          nan
# 1307      0      0      2656    7,225        C                1       adulto
# 1308      0      0      2670    7,225        C                1       adulto
# 1309      0      0    315082    7,875        S                1       adulto
#
# 0     last_name                    name    title mini_last_name  n_familiares
# 1171       Sage            Thomas Henry   Master            Sag            10
# 1172       Sage           William Henry   Master            Sag            10
# 1173       Sage                     Ada     Miss            Sag            10
# 1174       Sage        Constance Gladys     Miss            Sag            10
# 1175       Sage   Dorothy Edith "Dolly"     Miss            Sag            10
# ...         ...                     ...      ...            ...           ...
# 1303     Yousif                   Wazli       Mr            You             0
# 1304   Yousseff                 Gerious       Mr            You             0
# 1307   Zakarian             Mapriededer       Mr            Zak             0
# 1308   Zakarian                   Ortin       Mr            Zak             0
# 1309  Zimmerman                     Leo       Mr            Zim             0
#
# [709 rows x 18 columns]

# %%
# Podemos armar un dataframe a partir de cada grupo!
dfs = {} # Armo el diccionario vacío
for name, group in grouped_pclass:
  dfs[f"pclass_{name}"] = group

# %%
# Traigo el dataframe con key pclass_1 dentro del diccionario dfs
dfs['pclass_1']
# Out:
# 0    pclass  survived                                       name_raw     sex  \
# 112       1         1                 Fortune, Miss. Alice Elizabeth  female
# 113       1         1                     Fortune, Miss. Ethel Flora  female
# 114       1         1                     Fortune, Miss. Mabel Helen  female
# 115       1         0                 Fortune, Mr. Charles Alexander    male
# 9         1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# ..      ...       ...                                            ...     ...
# 319       1         0         Williams-Lambert, Mr. Fletcher Fellows    male
# 320       1         1                      Wilson, Miss. Helen Alice  female
# 321       1         1                              Woolner, Mr. Hugh    male
# 322       1         0                             Wright, Mr. George    male
# 323       1         1                       Young, Miss. Marie Grice  female
#
# 0     age  sibsp  parch    ticket      fare embarked boat  viaja_solo  \
# 112  24.0      3      2     19950       263        S   10           0
# 113  28.0      3      2     19950       263        S   10           0
# 114  23.0      3      2     19950       263        S   10           0
# 115  19.0      3      2     19950       263        S                0
# 9    53.0      2      0     11769   51,4792        S    D           0
# ..    ...    ...    ...       ...       ...      ...  ...         ...
# 319   NaN      0      0    113510        35        S                1
# 320  31.0      0      0     16966     134,5        C    3           1
# 321   NaN      0      0     19947      35,5        S    D           1
# 322  62.0      0      0    113807     26,55        S                1
# 323  36.0      0      0  PC 17760  135,6333        C    8           1
#
# 0   rango_etario         last_name                             name  title  \
# 112       adulto           Fortune                  Alice Elizabeth   Miss
# 113       adulto           Fortune                      Ethel Flora   Miss
# 114       adulto           Fortune                      Mabel Helen   Miss
# 115  adolescente           Fortune                Charles Alexander     Mr
# 9         adulto          Appleton   Edward Dale (Charlotte Lamson)    Mrs
# ..           ...               ...                              ...    ...
# 319          nan  Williams-Lambert                 Fletcher Fellows     Mr
# 320       adulto            Wilson                      Helen Alice   Miss
# 321          nan           Woolner                             Hugh     Mr
# 322      anciano            Wright                           George     Mr
# 323       adulto             Young                      Marie Grice   Miss
#
# 0   mini_last_name  n_familiares
# 112            For             5
# 113            For             5
# 114            For             5
# 115            For             5
# 9              App             2
# ..             ...           ...
# 319            Wil             0
# 320            Wil             0
# 321            Woo             0
# 322            Wri             0
# 323            You             0
#
# [323 rows x 18 columns]

# %%
# También se puede usar el metodo específico
grouped_pclass.get_group(1)
# Out:
# 0    pclass  survived                                       name_raw     sex  \
# 112       1         1                 Fortune, Miss. Alice Elizabeth  female
# 113       1         1                     Fortune, Miss. Ethel Flora  female
# 114       1         1                     Fortune, Miss. Mabel Helen  female
# 115       1         0                 Fortune, Mr. Charles Alexander    male
# 9         1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# ..      ...       ...                                            ...     ...
# 319       1         0         Williams-Lambert, Mr. Fletcher Fellows    male
# 320       1         1                      Wilson, Miss. Helen Alice  female
# 321       1         1                              Woolner, Mr. Hugh    male
# 322       1         0                             Wright, Mr. George    male
# 323       1         1                       Young, Miss. Marie Grice  female
#
# 0     age  sibsp  parch    ticket      fare embarked boat  viaja_solo  \
# 112  24.0      3      2     19950       263        S   10           0
# 113  28.0      3      2     19950       263        S   10           0
# 114  23.0      3      2     19950       263        S   10           0
# 115  19.0      3      2     19950       263        S                0
# 9    53.0      2      0     11769   51,4792        S    D           0
# ..    ...    ...    ...       ...       ...      ...  ...         ...
# 319   NaN      0      0    113510        35        S                1
# 320  31.0      0      0     16966     134,5        C    3           1
# 321   NaN      0      0     19947      35,5        S    D           1
# 322  62.0      0      0    113807     26,55        S                1
# 323  36.0      0      0  PC 17760  135,6333        C    8           1
#
# 0   rango_etario         last_name                             name  title  \
# 112       adulto           Fortune                  Alice Elizabeth   Miss
# 113       adulto           Fortune                      Ethel Flora   Miss
# 114       adulto           Fortune                      Mabel Helen   Miss
# 115  adolescente           Fortune                Charles Alexander     Mr
# 9         adulto          Appleton   Edward Dale (Charlotte Lamson)    Mrs
# ..           ...               ...                              ...    ...
# 319          nan  Williams-Lambert                 Fletcher Fellows     Mr
# 320       adulto            Wilson                      Helen Alice   Miss
# 321          nan           Woolner                             Hugh     Mr
# 322      anciano            Wright                           George     Mr
# 323       adulto             Young                      Marie Grice   Miss
#
# 0   mini_last_name  n_familiares
# 112            For             5
# 113            For             5
# 114            For             5
# 115            For             5
# 9              App             2
# ..             ...           ...
# 319            Wil             0
# 320            Wil             0
# 321            Woo             0
# 322            Wri             0
# 323            You             0
#
# [323 rows x 18 columns]

# %% [markdown]
# **Funciones de Agregación**
#
# Las funciones de agregación son aquellas que calculan una variable por grupo.
#
# Métricas Básicas:
#
# *   Suma: .sum()
# *   Count: .count()
# *   Count Distinct: .nunique()
# *   Máximo: .max()
# *   Mínimo: .min()
# *   Media: .mean()
# *   Mediana: .median()
# *   Desviación Standar: .std()
# *   Varianza: .var()
#
# Acumuladas:
#
# *   Contar acumulada: .cumcount()
# *   Suma acumulada: .cumsum()
# *   Máximo acumulativo: .cummax()
# *   Mínimo acumulativo: .cummin()
#
# Cambios dentro del grupo:
#
# *   Cambios crecientes: .is_monotonic_increasing()
# *   Cambios decreciente: .is_monotonic_decreasing()
#
# Posición:
#
# *   Primero del grupo: .first()
# *   Último del grupo: .last()
# *   Fila enésima del grupo: .nth()
# *   Rango del valor en cada grupo en base a una métrica: .rank()

# %%
# Ej: Cantidad de campos únicos
grouped_pclass.nunique()
# Out:
# 0       survived  name_raw  sex  age  sibsp  parch  ticket  fare  embarked  \
# pclass
# 1              2       323    2   65      4      5     188   107         4
# 2              2       277    2   65      4      4     192    48         3
# 3              2       707    2   79      7      8     549   134         3
#
# 0       boat  viaja_solo  rango_etario  last_name  name  title  \
# pclass
# 1         22           2             5        229   316     16
# 2         13           2             5        199   257      7
# 3         19           2             5        480   603      5
#
# 0       mini_last_name  n_familiares
# pclass
# 1                  178             6
# 2                  170             6
# 3                  346             9

# %% [markdown]
# **Agrupar por varias columnas**

# %%
grouped_segmentation = df[['sex','pclass','age',	'sibsp','parch']].groupby(['sex','pclass']).mean() # Usamos solo algunas columnas, agrupamos y hacemos el promedio
grouped_segmentation
# Out:
# 0                    age     sibsp     parch
# sex    pclass
# female 1       37.037594  0.555556  0.472222
#        2       27.499191  0.500000  0.650943
#        3       22.185307  0.791667  0.731481
# male   1       41.029250  0.340782  0.279330
#        2       30.815401  0.327485  0.192982
#        3       25.962273  0.470588  0.255578

# %% [markdown]
# **Agrupamos usando distintas func de agregación**

# %%
grouped_segmentation_agg = df.groupby(['sex','rango_etario']).aggregate({'pclass': 'mean',
                                                                         'survived': 'mean',
                                                                         'fare': 'max',
                                                                         'name': 'count',
                                                                         'last_name': 'last'})
grouped_segmentation_agg
# Out:
# 0                      pclass  survived     fare  name last_name
# sex    rango_etario
# female adolescente   2.305085  0.762712  91,0792    59   Taussig
#        adulto        1.927007  0.770073     93,5   274     Young
#        anciano       1.272727  0.818182   9,5875    11     Stone
#        nan           2.679487  0.602564  89,1042    78    Thorne
#        niño          2.659091  0.613636     46,9    44   Allison
# male   adolescente   2.611111  0.097222      9,5    72    Thayer
#        adulto        2.266272  0.193294     93,5   507  Williams
#        anciano       1.586207  0.103448   9,6875    29    Wright
#        nan           2.627027  0.140541      9,5   185   Woolner
#        niño          2.620000  0.540000     9,35    50   Spedden

# %% [markdown]
# ---
#
#
# ### **Joins de Dataframes**
#
#
# ---

# %%
# Hagamos mean_age_pclass (la media de la edad por clase) y joiniemosla con el df original
df_pclass_agg_age = df[['pclass','age']].groupby('pclass').mean().reset_index()
df_pclass_agg_age
# Out:
# 0  pclass        age
# 0       1  39.159918
# 1       2  29.506705
# 2       3  24.816367

# %%
# Joineo información agregada por pclass:

df_merge = pd.merge(df,df_pclass_agg_age, how = 'left',
                    left_on = ['pclass'], right_on = ['pclass'], suffixes = ['','_mean'])
                    # Nota: También se puede joinear por indice cambiando left_on a left_index = True y right_on a right_index = True

df_merge
# Out:
# 0     pclass  survived                                name_raw     sex   age  \
# 0          3         0              Sage, Master. Thomas Henry    male   NaN
# 1          3         0             Sage, Master. William Henry    male  14.5
# 2          3         0                         Sage, Miss. Ada  female   NaN
# 3          3         0            Sage, Miss. Constance Gladys  female   NaN
# 4          3         0       Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# ...      ...       ...                                     ...     ...   ...
# 1304       1         0  Williams-Lambert, Mr. Fletcher Fellows    male   NaN
# 1305       1         1               Wilson, Miss. Helen Alice  female  31.0
# 1306       1         1                       Woolner, Mr. Hugh    male   NaN
# 1307       1         0                      Wright, Mr. George    male  62.0
# 1308       1         1                Young, Miss. Marie Grice  female  36.0
#
# 0     sibsp  parch    ticket      fare embarked boat  viaja_solo rango_etario  \
# 0         8      2  CA. 2343     69,55        S                0          nan
# 1         8      2  CA. 2343     69,55        S                0  adolescente
# 2         8      2  CA. 2343     69,55        S                0          nan
# 3         8      2  CA. 2343     69,55        S                0          nan
# 4         8      2  CA. 2343     69,55        S                0          nan
# ...     ...    ...       ...       ...      ...  ...         ...          ...
# 1304      0      0    113510        35        S                1          nan
# 1305      0      0     16966     134,5        C    3           1       adulto
# 1306      0      0     19947      35,5        S    D           1          nan
# 1307      0      0    113807     26,55        S                1      anciano
# 1308      0      0  PC 17760  135,6333        C    8           1       adulto
#
# 0            last_name                    name    title mini_last_name  \
# 0                 Sage            Thomas Henry   Master            Sag
# 1                 Sage           William Henry   Master            Sag
# 2                 Sage                     Ada     Miss            Sag
# 3                 Sage        Constance Gladys     Miss            Sag
# 4                 Sage   Dorothy Edith "Dolly"     Miss            Sag
# ...                ...                     ...      ...            ...
# 1304  Williams-Lambert        Fletcher Fellows       Mr            Wil
# 1305            Wilson             Helen Alice     Miss            Wil
# 1306           Woolner                    Hugh       Mr            Woo
# 1307            Wright                  George       Mr            Wri
# 1308             Young             Marie Grice     Miss            You
#
# 0     n_familiares   age_mean
# 0               10  24.816367
# 1               10  24.816367
# 2               10  24.816367
# 3               10  24.816367
# 4               10  24.816367
# ...            ...        ...
# 1304             0  39.159918
# 1305             0  39.159918
# 1306             0  39.159918
# 1307             0  39.159918
# 1308             0  39.159918
#
# [1309 rows x 19 columns]

# %%
df_merge.head(50)
# Out:
# 0   pclass  survived                                           name_raw  \
# 0        3         0                         Sage, Master. Thomas Henry
# 1        3         0                        Sage, Master. William Henry
# 2        3         0                                    Sage, Miss. Ada
# 3        3         0                       Sage, Miss. Constance Gladys
# 4        3         0                  Sage, Miss. Dorothy Edith "Dolly"
# 5        3         0                            Sage, Miss. Stella Anna
# 6        3         0                           Sage, Mr. Douglas Bullen
# 7        3         0                                Sage, Mr. Frederick
# 8        3         0                           Sage, Mr. George John Jr
# 9        3         0                     Goodwin, Master. Harold Victor
# 10       3         0                    Goodwin, Master. Sidney Leonard
# 11       3         0                 Goodwin, Master. William Frederick
# 12       3         0                        Goodwin, Miss. Jessie Allis
# 13       3         0                         Goodwin, Miss. Lillian Amy
# 14       3         0                        Goodwin, Mr. Charles Edward
# 15       3         0            Andersson, Master. Sigvard Harald Elias
# 16       3         0                 Andersson, Miss. Ebba Iris Alfrida
# 17       3         0                  Andersson, Miss. Ellis Anna Maria
# 18       3         1                    Andersson, Miss. Erna Alexandra
# 19       3         0             Andersson, Miss. Ida Augusta Margareta
# 20       3         0               Andersson, Miss. Ingeborg Constanzia
# 21       3         0                  Andersson, Miss. Sigrid Elisabeth
# 22       3         0                        Asplund, Master. Carl Edgar
# 23       3         0              Asplund, Master. Clarence Gustaf Hugo
# 24       3         1                  Asplund, Master. Edvin Rojj Felix
# 25       3         0                       Asplund, Master. Filip Oscar
# 26       3         1                     Asplund, Miss. Lillian Gertrud
# 27       3         0                       Panula, Master. Eino Viljami
# 28       3         0                         Panula, Master. Juha Niilo
# 29       3         0                       Panula, Master. Urho Abraham
# 30       3         0                          Panula, Mr. Ernesti Arvid
# 31       3         0                           Panula, Mr. Jaako Arnold
# 32       3         0                               Rice, Master. Albert
# 33       3         0                               Rice, Master. Arthur
# 34       3         0                                 Rice, Master. Eric
# 35       3         0                               Rice, Master. Eugene
# 36       3         0                          Rice, Master. George Hugh
# 37       3         1  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...
# 38       3         1                           Kink-Heilmann, Mr. Anton
# 39       3         0                      Lefebre, Master. Henry Forbes
# 40       3         0                                 Lefebre, Miss. Ida
# 41       3         0                             Lefebre, Miss. Jeannie
# 42       3         0                            Lefebre, Miss. Mathilde
# 43       3         0                     Palsson, Master. Gosta Leonard
# 44       3         0                        Palsson, Master. Paul Folke
# 45       3         0                         Palsson, Miss. Stina Viola
# 46       3         0                      Palsson, Miss. Torborg Danira
# 47       3         0                              Skoog, Master. Harald
# 48       3         0                       Skoog, Master. Karl Thorsten
# 49       3         0                                 Skoog, Miss. Mabel
#
# 0      sex   age  sibsp  parch    ticket     fare embarked boat  viaja_solo  \
# 0     male   NaN      8      2  CA. 2343    69,55        S                0
# 1     male  14.5      8      2  CA. 2343    69,55        S                0
# 2   female   NaN      8      2  CA. 2343    69,55        S                0
# 3   female   NaN      8      2  CA. 2343    69,55        S                0
# 4   female   NaN      8      2  CA. 2343    69,55        S                0
# 5   female   NaN      8      2  CA. 2343    69,55        S                0
# 6     male   NaN      8      2  CA. 2343    69,55        S                0
# 7     male   NaN      8      2  CA. 2343    69,55        S                0
# 8     male   NaN      8      2  CA. 2343    69,55        S                0
# 9     male   9.0      5      2   CA 2144     46,9        S                0
# 10    male   1.0      5      2   CA 2144     46,9        S                0
# 11    male  11.0      5      2   CA 2144     46,9        S                0
# 12  female  10.0      5      2   CA 2144     46,9        S                0
# 13  female  16.0      5      2   CA 2144     46,9        S                0
# 14    male  14.0      5      2   CA 2144     46,9        S                0
# 15    male   4.0      4      2    347082   31,275        S                0
# 16  female   6.0      4      2    347082   31,275        S                0
# 17  female   2.0      4      2    347082   31,275        S                0
# 18  female  17.0      4      2   3101281    7,925        S    D           0
# 19  female  38.0      4      2    347091    7,775        S                0
# 20  female   9.0      4      2    347082   31,275        S                0
# 21  female  11.0      4      2    347082   31,275        S                0
# 22    male   5.0      4      2    347077  31,3875        S                0
# 23    male   9.0      4      2    347077  31,3875        S                0
# 24    male   3.0      4      2    347077  31,3875        S   15           0
# 25    male  13.0      4      2    347077  31,3875        S                0
# 26  female   5.0      4      2    347077  31,3875        S   15           0
# 27    male   1.0      4      1   3101295  39,6875        S                0
# 28    male   7.0      4      1   3101295  39,6875        S                0
# 29    male   2.0      4      1   3101295  39,6875        S                0
# 30    male  16.0      4      1   3101295  39,6875        S                0
# 31    male  14.0      4      1   3101295  39,6875        S                0
# 32    male  10.0      4      1    382652   29,125        Q                0
# 33    male   4.0      4      1    382652   29,125        Q                0
# 34    male   7.0      4      1    382652   29,125        Q                0
# 35    male   2.0      4      1    382652   29,125        Q                0
# 36    male   8.0      4      1    382652   29,125        Q                0
# 37  female  33.0      3      0   3101278    15,85        S                0
# 38    male  29.0      3      1    315153   22,025        S    2           0
# 39    male   NaN      3      1      4133  25,4667        S                0
# 40  female   NaN      3      1      4133  25,4667        S                0
# 41  female   NaN      3      1      4133  25,4667        S                0
# 42  female   NaN      3      1      4133  25,4667        S                0
# 43    male   2.0      3      1    349909   21,075        S                0
# 44    male   6.0      3      1    349909   21,075        S                0
# 45  female   3.0      3      1    349909   21,075        S                0
# 46  female   8.0      3      1    349909   21,075        S                0
# 47    male   4.0      3      2    347088     27,9        S                0
# 48    male  10.0      3      2    347088     27,9        S                0
# 49  female   9.0      3      2    347088     27,9        S                0
#
# 0  rango_etario      last_name                                      name  \
# 0           nan           Sage                              Thomas Henry
# 1   adolescente           Sage                             William Henry
# 2           nan           Sage                                       Ada
# 3           nan           Sage                          Constance Gladys
# 4           nan           Sage                     Dorothy Edith "Dolly"
# 5           nan           Sage                               Stella Anna
# 6           nan           Sage                            Douglas Bullen
# 7           nan           Sage                                 Frederick
# 8           nan           Sage                            George John Jr
# 9          niño        Goodwin                             Harold Victor
# 10         niño        Goodwin                            Sidney Leonard
# 11         niño        Goodwin                         William Frederick
# 12         niño        Goodwin                              Jessie Allis
# 13  adolescente        Goodwin                               Lillian Amy
# 14  adolescente        Goodwin                            Charles Edward
# 15         niño      Andersson                      Sigvard Harald Elias
# 16         niño      Andersson                         Ebba Iris Alfrida
# 17         niño      Andersson                          Ellis Anna Maria
# 18  adolescente      Andersson                            Erna Alexandra
# 19       adulto      Andersson                     Ida Augusta Margareta
# 20         niño      Andersson                       Ingeborg Constanzia
# 21         niño      Andersson                          Sigrid Elisabeth
# 22         niño        Asplund                                Carl Edgar
# 23         niño        Asplund                      Clarence Gustaf Hugo
# 24         niño        Asplund                          Edvin Rojj Felix
# 25  adolescente        Asplund                               Filip Oscar
# 26         niño        Asplund                           Lillian Gertrud
# 27         niño         Panula                              Eino Viljami
# 28         niño         Panula                                Juha Niilo
# 29         niño         Panula                              Urho Abraham
# 30  adolescente         Panula                             Ernesti Arvid
# 31  adolescente         Panula                              Jaako Arnold
# 32         niño           Rice                                    Albert
# 33         niño           Rice                                    Arthur
# 34         niño           Rice                                      Eric
# 35         niño           Rice                                    Eugene
# 36         niño           Rice                               George Hugh
# 37       adulto      Backstrom   Karl Alfred (Maria Mathilda Gustafsson)
# 38       adulto  Kink-Heilmann                                     Anton
# 39          nan        Lefebre                              Henry Forbes
# 40          nan        Lefebre                                       Ida
# 41          nan        Lefebre                                   Jeannie
# 42          nan        Lefebre                                  Mathilde
# 43         niño        Palsson                             Gosta Leonard
# 44         niño        Palsson                                Paul Folke
# 45         niño        Palsson                               Stina Viola
# 46         niño        Palsson                            Torborg Danira
# 47         niño          Skoog                                    Harald
# 48         niño          Skoog                             Karl Thorsten
# 49         niño          Skoog                                     Mabel
#
# 0     title mini_last_name  n_familiares   age_mean
# 0    Master            Sag            10  24.816367
# 1    Master            Sag            10  24.816367
# 2      Miss            Sag            10  24.816367
# 3      Miss            Sag            10  24.816367
# 4      Miss            Sag            10  24.816367
# 5      Miss            Sag            10  24.816367
# 6        Mr            Sag            10  24.816367
# 7        Mr            Sag            10  24.816367
# 8        Mr            Sag            10  24.816367
# 9    Master            Goo             7  24.816367
# 10   Master            Goo             7  24.816367
# 11   Master            Goo             7  24.816367
# 12     Miss            Goo             7  24.816367
# 13     Miss            Goo             7  24.816367
# 14       Mr            Goo             7  24.816367
# 15   Master            And             6  24.816367
# 16     Miss            And             6  24.816367
# 17     Miss            And             6  24.816367
# 18     Miss            And             6  24.816367
# 19     Miss            And             6  24.816367
# 20     Miss            And             6  24.816367
# 21     Miss            And             6  24.816367
# 22   Master            Asp             6  24.816367
# 23   Master            Asp             6  24.816367
# 24   Master            Asp             6  24.816367
# 25   Master            Asp             6  24.816367
# 26     Miss            Asp             6  24.816367
# 27   Master            Pan             5  24.816367
# 28   Master            Pan             5  24.816367
# 29   Master            Pan             5  24.816367
# 30       Mr            Pan             5  24.816367
# 31       Mr            Pan             5  24.816367
# 32   Master            Ric             5  24.816367
# 33   Master            Ric             5  24.816367
# 34   Master            Ric             5  24.816367
# 35   Master            Ric             5  24.816367
# 36   Master            Ric             5  24.816367
# 37      Mrs            Bac             3  24.816367
# 38       Mr            Kin             4  24.816367
# 39   Master            Lef             4  24.816367
# 40     Miss            Lef             4  24.816367
# 41     Miss            Lef             4  24.816367
# 42     Miss            Lef             4  24.816367
# 43   Master            Pal             4  24.816367
# 44   Master            Pal             4  24.816367
# 45     Miss            Pal             4  24.816367
# 46     Miss            Pal             4  24.816367
# 47   Master            Sko             5  24.816367
# 48   Master            Sko             5  24.816367
# 49     Miss            Sko             5  24.816367

# %% [markdown]
# ---
#
#
# ### **CrossTable**
#
#
# ---
#
#
# Equivalente a las tablas Pivot ( o Dinámicas) de Excel.

# %%
# Ej con totales:

cross = pd.crosstab(df['rango_etario'],df['pclass'], values=df['survived'], aggfunc='mean',
                    margins = True, margins_name = 'Totales' )
cross
# Out:
# pclass               1         2         3   Totales
# rango_etario
# adolescente   0.809524  0.407407  0.289157  0.396947
# adulto        0.646552  0.391089  0.230548  0.395647
# anciano       0.384615  0.125000  0.166667  0.300000
# nan           0.487179  0.250000  0.240385  0.277567
# niño          0.800000  1.000000  0.400000  0.574468
# Totales       0.619195  0.429603  0.255289  0.381971

# %% [markdown]
# **Visualización con Heatmap**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cross = pd.crosstab(df['rango_etario'],df['pclass'], values=df['survived'], aggfunc='mean')

fig, ax = plt.subplots(figsize=(12,8))
sns.heatmap(cross, cmap= 'Blues', annot=True)
# Out:
# <Axes: xlabel='pclass', ylabel='rango_etario'>

# %% [markdown]
# ---
#
#
# ### **Guardamos el Dataframe**
#
#
# ---

# %% [markdown]
# **En un CSV**

# %%
df_merge.to_csv('output.csv',index=False)

# %% [markdown]
# **En un Google Spreadsheet**

# %%
# Dirección del archivo
wb = gc.open_by_url('https://docs.google.com/spreadsheets/d/16AiilYU0DbGnEoQsvPuLtRjLpDaK4dMOmrgSAGnyyp4')

# Especifico Hoja del Spreadsheet
sheet = wb.worksheet('output')

# Elimino el contenido anterior
sheet.clear()

# Guardo el dataframe
set_with_dataframe(sheet, df_merge, include_index=False)

# %% [markdown]
# ---
#
#
# ### **Ejercicios**
#
#
# ---

# %% [markdown]
# ¿Cuál es el precio promedio que se pagó por un Ticket? (Fare)

# %% [markdown]
# ¿Que le sucedió a la pasajera Mabel Skoog?
